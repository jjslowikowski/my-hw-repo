# %% [markdown]
# # Project 4
#
# In this project, you will summarize and present your analysis from Projects 1-3.

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer:
#
# Can we create a predictive model to determine a candidate's probability of admission based on a set of application factors from a cross-sectional dataset containg (GPA, GRE Score, Prestige,Amission Status).

# %% [markdown]
# ### Dataset:  Write up a description of your data and any cleaning that was completed

# %% [markdown]
# Answer:
#
# The dataset provided information on 400 applicants to graduate school. These data included the applicant's GPA, GRE Score, prestige level of the school they attended prior to application, and whether they were admitted.
#
# Three rows contained null values and were subsequently dropped from the overall analysis leaving 397 candidates for evaluation. The following descriptive statistics are for those candidates:

# %%
#pd.DataFrame(df.groupby(df['admit']).describe()).T

# %%
#df[['prestige','admit']].groupby('prestige').describe()

# %% [markdown]
# ### Demo: Provide a table that explains the data by admission status

# %% [markdown]
# Mean (STD) or counts by admission status for each variable  (derived from above code)
#
# | Not Admitted | Admitted
# ---| ---|---
# GPA | 3.35(0.38)  | 3.49(0.37)
# GRE |573.5(116.1) | 618.6(109.3)
# Prestige 1 | 46% | 54%
# Prestige 2 | 64% | 36%
# Prestige 3 |77% | 23%
# Prestige 4 |82% | 18%

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
import seaborn as sns
import bokeh as bk
# Out:
# C:\Users\Jacek\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df_raw = pd.read_csv("../assets/admissions.csv")
df = pd.DataFrame(df_raw.dropna()) 
#df.count().unstack()
#dataset.loc[dataset['NumberOfOpenCreditLinesAndLoans'] == 0, 'NumberOfOpenCreditLinesAndLoans'] == 1
#df.apply(df['admit']==0)

# %% [markdown]
# ### Methods: Write up the methods used in your analysis

# %% [markdown]
# Answer:
#
# We used the cleaned data to create a linear regression model that was then fit to cartesian map of all possible GPA/GRE/Prestige combinations.

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Answer:
#
# The output from this application provided insights into the fact that the strength of a student's school ranking has the strongest effect on the probability of a candidate admission when GPA/GRE scores were the same. For example, the probability of a candidate's admission with GPA of 3.8 and GRE of 750 across the 4 school rank categories visibly skewed in favor of applicants from school rank 1.
#
# That being said, the difference in probabilty of acceptance between the rank 3/4 schools is much smaller than the gain of being at a tier 1 vs tier 2 school.

# %% [markdown]
# ### Visuals: Provide a table or visualization of these results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Discussion: Write up your discussion and future steps

# %% [markdown]
# Answer: Students applying from a school with the highest prestige level have a much higher chance of admission when compared to candidates with similar GPA/GRE scores from lower-tier schools. This was a relatively small datset from an unknown time period. It would be best to test our predictive model on more recent data and then train it on a larger dataset with some of the other classification models we've learned so far.
